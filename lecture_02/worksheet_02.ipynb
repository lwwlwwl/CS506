# %% [markdown]
# # Worksheet 02
#
# Name: Yuchen Lu \
# UID: U56150111
#
# ### Topics
#
# - Effective Programming
#
# ### Effective Programming
#
# a) What is a drawback of the top down approach?

# %% [markdown]
# The top down approach starts at the root by writing a pseudo code, prentending that I have all the helper functions, then break it down into smaller pieces to implement. The drawback is that Yyou don't have the runnable code until the end to test it.

# %% [markdown]
# b) What is a drawback of the bottom up approach?

# %% [markdown]
# Bottom up approach builds all pieces up front and compose them together. You may not know everything up front. It is hard to know what the pieces are and how to compose them.

# %% [markdown]
# c) What are 3 things you can do to have a better debugging experience?

# %% [markdown]
# 1. Do one thing
# 2. Wrtie many functions with small bodies instead of one function with a large body.
# 3. Keep the code simple (boring code is good code) so that the codes are easier to read and deubg.

# %% [markdown]
# d) Follow along with the live coding. You can write your code here:

# %%
# eight queens 
class Board:
    def __init__(self):
        self.board = [["_" for _ in range(8)] for _ in range(8)]

    def __repr__(self):
        res = ""
        for row in self.board:
            for col in row:
                res += col + " "
            res += "\n"
        return res
    
    def is_on_board(self, row, col):
        return row >= 0 and row < 8 and col >= 0 and col < 8
    
    def is_legal_diag(self, row, col):
        for x in range(len(self.board)):
            if self.is_on_board(row-x, col-x) and self.board[row-x][col-x] == 'Q':
                return False
            
            if self.is_on_board(row-x, col+x) and self.board[row-x][col+x] == 'Q':
                return False
            
            if self.is_on_board(row+x, col-x) and self.board[row+x][col-x] == 'Q':
                return False
            
            if self.is_on_board(row+x, col+x) and self.board[row+x][col+x] == 'Q':
                return False
        return True
    
    def is_legal(self, row, col):
        if "Q" in self.board[row]:
            return False
        elif not self.is_legal_diag(row, col):
            return False
        else:
            for x in range(len(self.board[col])):
                if self.board[x][col] == 'Q':
                    return False
        return True
    
    def set_queen_at(self, row, col):
        self.board[row][col] = 'Q'

    def unset_queen(self, row, col):
        self.board[row][col] = '_'
    
    def get_queen_on(self, row):
        for col in range(len(self.board)):
            if self.board[row][col] == 'Q':
                return col
            
        raise ValueError("No queen on row {}".format(row))
    
    def search(self):
        row = 0
        col = 0

        nSol = 0

        while row >= 0:
            if row < 8:
                if self.is_legal(row, col):
                    self.set_queen_at(row, col)
                    row += 1
                    col = 0
                else:
                    col += 1
                    while col > 7:
                        col = self.get_queen_on(row-1)
                        self.unset_queen(row-1, col)
                        col += 1
                        row -= 1
            else: 
                nSol += 1
                print("FOUND SOLUTION: ", nSol)
                print(self)
                row -= 1
                col = self.get_queen_on(row)
                self.unset_queen(row, col)
                col += 1
                while col > 7:
                    col = self.get_queen_on(row-1)
                    self.unset_queen(row-1, col)
                    col += 1
                    row -= 1
                    

my_board = Board()
my_board.search()
# Out:
# FOUND SOLUTION:  1
# Q _ _ _ _ _ _ _
# _ _ _ _ Q _ _ _
# _ _ _ _ _ _ _ Q
# _ _ _ _ _ Q _ _
# _ _ Q _ _ _ _ _
# _ _ _ _ _ _ Q _
# _ Q _ _ _ _ _ _
# _ _ _ Q _ _ _ _
#
# FOUND SOLUTION:  2
# Q _ _ _ _ _ _ _
# _ _ _ _ _ Q _ _
# _ _ _ _ _ _ _ Q
# _ _ Q _ _ _ _ _
# _ _ _ _ _ _ Q _
# _ _ _ Q _ _ _ _
# _ Q _ _ _ _ _ _
# _ _ _ _
 _ _ _
# Q _ _ _ _ _ _ _
# _ _ _ _ _ _ Q _
# _ _ _ Q _ _ _ _
# _ _ _ _ _ Q _ _
#
# FOUND SOLUTION:  91
# _ _ _ _ _ _ _ Q
# _ _ Q _ _ _ _ _
# Q _ _ _ _ _ _ _
# _ _ _ _ _ Q _ _
# _ Q _ _ _ _ _ _
# _ _ _ _ Q _ _ _
# _ _ _ _ _ _ Q _
# _ _ _ Q _ _ _ _
#
# FOUND SOLUTION:  92
# _ _ _ _ _ _ _ Q
# _ _ _ Q _ _ _ _
# Q _ _ _ _ _ _ _
# _ _ Q _ _ _ _ _
# _ _ _ _ _ Q _ _
# _ Q _ _ _ _ _ _
# _ _ _ _ _ _ Q _
# _ _ _ _ Q _ _ _
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/yuchen/Desktop/CS506 - Material/CS506/lecture_02/worksheet_02.ipynb Cell 8 line 9
#      <a href='vscode-notebook-cell:/Users/yuchen/Desktop/CS506%20-%20Material/CS506/lecture_02/worksheet_02.ipynb#X10sZmlsZQ%3D%3D?line=86'>87</a>                     row -= 1
#      <a href='vscode-notebook-cell:/Users/yuchen/Desktop/CS506%20-%20Material/CS506/lecture_02/worksheet_02.ipynb#X10sZmlsZQ%3D%3D?line=89'>90</a> my_board = Board()
# ---> <a href='vscode-notebook-cell:/Users/yuchen/Desktop/CS506%20-%20Material/CS506/lecture_02/worksheet_02.ipynb#X10sZmlsZQ%3D%3D?line=90'>91</a> my_board.search()
#
# /Users/yuchen/Desktop/CS506 - Material/CS506/lecture_02/worksheet_02.ipynb Cell 8 line 7
#      <a href='vscode-notebook-cell:/Users/yuchen/Desktop/CS506%20-%20Material/CS506/lecture_02/worksheet_02.ipynb#X10sZmlsZQ%3D%3D?line=68'>69</a> col += 1
#      <a href='vscode-notebook-cell:/Users/yuchen/Desktop/CS506%20-%20Material/CS506/lecture_02/worksheet_02.ipynb#X10sZmlsZQ%3D%3D?line=69'>70</a> while col > 7:
# ---> <a href='vscode-notebook-cell:/Users/yuchen/Desktop/CS506%20-%20Material/CS506/lecture_02/worksheet_02.ipynb#X10sZmlsZQ%3D%3D?line=70'>71</a>     col = self.get_queen_on(row-1)
#      <a href='vscode-notebook-cell:/Users/yuchen/Desktop/CS506%20-%20Material/CS506/lecture_02/worksheet_02.ipynb#X10sZmlsZQ%3D%3D?line=71'>72</a>     self.unset_queen(row-1, col)
#      <a href='vscode-notebook-cell:/Users/yuchen/Desktop/CS506%20-%20Material/CS506/lecture_02/worksheet_02.ipynb#X10sZmlsZQ%3D%3D?line=72'>73</a>     col += 1
#
# /Users/yuchen/Desktop/CS506 - Material/CS506/lecture_02/worksheet_02.ipynb Cell 8 line 5
#      <a href='vscode-notebook-cell:/Users/yuchen/Desktop/CS506%20-%20Material/CS506/lecture_02/worksheet_02.ipynb#X10sZmlsZQ%3D%3D?line=50'>51</a>     if self.board[row][col] == 'Q':
#      <a href='vscode-notebook-cell:/Users/yuchen/Desktop/CS506%20-%20Material/CS506/lecture_02/worksheet_02.ipynb#X10sZmlsZQ%3D%3D?line=51'>52</a>         return col
# ---> <a href='vscode-notebook-cell:/Users/yuchen/Desktop/CS506%20-%20Material/CS506/lecture_02/worksheet_02.ipynb#X10sZmlsZQ%3D%3D?line=53'>54</a> raise ValueError("No queen on row {}".format(row))
#
# ValueError: No queen on row -1
